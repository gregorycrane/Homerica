pharr2stand['ἅλς'] = 'ἅλς2'
pharr2stand['δεύομαι'] = 'δεύω2'
pharr2stand['ἐρύω'] = 'ἐρύω1'
pharr2stand['ἱερόν'] = 'ἱερός'
pharr2stand['ἐλάω'] = 'ἐλαύνω'
pharr2stand['μαχέομαι'] = 'μάχομαι'
pharr2stand['οὖρος'] = 'ὄρος'
pharr2stand['Tpῶes'] = 'Τρώς'
pharr2stand['Φθίη'] = 'Φθία'
pharr2stand['ἶσος'] = 'ἴσος'
pharr2stand['μετατρέπω'] = 'μετατρέπομαι'
pharr2stand['Τροίη'] = 'Τροία'
pharr2stand['ἀναιδείη'] = 'ἀναίδεια'
pharr2stand['εἴρω'] = 'εἶπον'
pharr2stand['ἄρ(α)'] = 'ἄρα'
pharr2stand['*Ἄις'] = 'Ἅιδης'


vocabs = {}
f = open('pharr.homgramm.xml')
for l in f:
    m = re.search('lesson([0-9]+)',l)
    if(m):
        curlesson = int(m[1])
        print('curlesson',curlesson)
    m = re.search('<item><foreign[^>]*>([^<]+)',l)
    if(m):
        curvoc = m[1]
        curvoc = re.sub('-(.)','\g<1>',curvoc)
        curvoc = re.sub('ῡ','υ',curvoc)
        curvoc = re.sub('ᾱ','α',curvoc)
        curvoc = re.sub('ῑ','ι',curvoc)
        if( curvoc in pharr2stand):
            curvoc = pharr2stand[curvoc]
        vocabs[curvoc] = curlesson
        print(curvoc,curlesson)

f.close()
# Out:
# curlesson 1
# μῆνις 1
# ἀείδω 1
# θεά 1
# Πηλείδης 1
# Ἀχιλλεύς 1
# οὐλόμενος 1
# ὅς 1
# μυρίος 1
# Ἀχαιός 1
# ἄλγος 1
# τίθημι 1
# πολύς 1
# δέ 1
# ἴφθιμος 1
# ψυχή 1
# Ἅιδης 1
# προιάπτω 1
# ἥρως 1
# αὐτός 1
# ἑλώριον 1
# τεύχω 1
# κύων 1
# οἰωνός 1
# τε 1
# δαίς1 1
# Ζεύς 1
# τελείω 1
# βουλή 1
# curlesson 2
# curlesson 3
# βουλή 3
# δεινή 3
# ἐν 3
# ἔχει 3
# ἔχουσι 3
# ἦν 3
# ἦσαν 3
# καί 3
# κακή 3
# καλή 3
# κλαγγή 3
# τίς 3
# τί 3
# Χρύση 3
# φίλος 3
# curlesson 4
# γάρ 4
# εἰσί/εἰσίν 4
# δέ 4
# ἐστί/ἐστίν 4
# ἐκ 4
# ἐπί 4
# θάλασσα 4
# θεά 4
# Κίλλα 4
# οὐ 4
# πάτρη 4
# πολλή 4
# πυρή 4
# ψυχή 4
# curlesson 5
# ἀείδω 5
# ἀ-1 5
# ἁνδάνω 5
# ἀτιμάζω 5
# βαίνω 5
# εἰς 5
# ἔχω 5
# καίω 5
# λύω 5
# ὀλέκω 5
# πέμπω 5
# τελείω 5
# τεύχω 5
# φέρω 5
# curlesson 6
# ἀγλαός 6
# ἀνά 6
# ἀπερείσιος 6
# ἄποινα 6
# Ἀχαιός 6
# δεινός 6
# ἑλώριον 6
# θεός 6
# θυμός 6
# κακός 6
# καλός 6
# λαός 6
# μυρίος 6
# νόσος 6
# οἰωνός 6
# πολύς 6
# στρατός 6
# φίλος 6
# curlesson 7
# curlesson 8
# ...

# %%
import os
import re


curlineword = ''
outf = open('voc.html','w')

print('<!DOCTYPE html>\n<html>\n<body>\n<svg height="5000" width="3000">',file=outf)

#print('<rect id="book01" x="100" y="20" height="400" width="40"  fill="rgb(200,200,200)" />',file=outf)

basex1 = 10
basey = 50

sumcolwidth = 5
sumcolgap = 2
sumrowheight = 5
sumrowgap = 2
booktot = 24

basex = basex1*2 + booktot* (sumcolwidth+sumcolgap)
curbook = 1
curwork = 1
wordsize = 6
lineheight = wordsize
linediv = 1
coldiv = wordsize
wordwidth = wordsize

def getstarty(cit):
    args = cit.split('.')
    y = basey + ((int(args[1])-1) % 100)*(lineheight+linediv)
    y = y +  int(((int(args[1])-1)%100)  / 10)*(lineheight+linediv)
    return(y)

def getstartx(cit,wordn):
    args = cit.split('.')
    x = basex + wordn*wordwidth + (int((int(args[1])-1)/100) * (maxlinelen+coldiv)*wordwidth)
    return (x)

def getxwidth(words):
    return(str(words * wordwidth))

linelens = {}
iltb = {}
maxlinelen = 0
sbreaks = {}
lineids = {}
maxbooklines = {}
workheights = {}
f = open('/Users/gcrane/github/gAGDT/data/xml/tlg0012.tlg00'+str(curwork)+'.perseus-grc1.tb.xml')

for l in f:
    m = re.search('<sent.+id="([^"]+)',l)
    if(m):
        sentid = m[1]
        if(curlineword):
            sbreaks[curlineword] = sentid
    m = re.search('tlg00'+str(curwork)+':([0-9]+\.[0-9]+)',l)
    if(m):
        
        linenum = m[1]
        workbook = int(linenum.split('.')[0])
        curline = int(linenum.split('.')[1])
        maxbooklines[workbook] = curline

        if( linenum in linelens):
            linelens[linenum] = linelens[linenum] + 1
        else:
            linelens[linenum] = 1
        if(linelens[linenum] > maxlinelen):
            maxlinelen = linelens[linenum]
            print('max',linenum,maxlinelen)
        curlineword = linenum+'.'+str(linelens[linenum])
        iltb[curlineword] = l

f.close()
print(maxlinelen)

for foo in sorted(maxbooklines):
    print('booklines',foo,maxbooklines[foo])
    wbook = foo
    curlines = maxbooklines[foo]
    x1 = basex1 + (wbook-1) * (sumcolwidth + sumcolgap)
    print('<rect id="book'+ str(wbook)+'"',end='',file=outf)
    if(wbook == curbook):
        print(' fill=rgb("200,200,200")',end='',file=outf)
    else:
        print(' fill="gray"',end='',file=outf)
    print(' x="' + str(x1) + '" width="' + str(sumcolwidth) + '" ',end='',file=outf)
    print(' y="' + str(basey) + '" height="' + str(int(curlines/5)) + '" ',end='',file=outf)
    print('/>',file=outf)
    

def drawline(cit,startw,words,fillcolor,baseid):
    useid = re.sub('(il)([0-9]\.)','\g<1>0\g<2>',baseid)
    useid = re.sub('\.([0-9])$','00\g<1>',useid)
    useid = re.sub('\.([0-9][0-9])$','0\g<1>',useid)
    useid = re.sub('\.([0-9][0-9])$','0\g<1>',useid)
    useid = re.sub('\.([0-9][0-9][0-9])','\g<1>',useid)
    starty = getstarty(cit)
    
    startx = getstartx(cit,startw)
    xwidth = getxwidth(words)
    endrect = '"" height="' + str(lineheight) + '" width="' + xwidth + '" fill="rgb('+fillcolor+')"/>' 

    print('<rect id="'+ useid + '" x="' + str(startx) + '" y="' + str(starty) + endrect,file=outf)

    print('<text id="popup.'+ useid + '" ',end='',file=outf)
    print('x="10" stroke="blue" ',end='',file=outf)
    print('y="30" ' ,end='',file=outf) 
    #print(' fill="black"',end='',file=outf)
    print(' fill=rgb"('+fillcolor+')"',end='',file=outf)
    print('font-size="30"  visibility="hidden">',end='',file=outf)
    print(baseid,end='',file=outf)
    print('<set attributeName="visibility" from="hidden" to="visible" ',end='',file=outf)
    print('begin="'+ useid +'.mouseover" end="' + useid +'.mouseout"/></text>',file=outf)

for foo in linelens:
    if( not re.search('^'+str(curbook)+'\.',foo)):
        continue

    rectid = 'il' + foo
    print('rectid',foo,linelens[foo])
    
    drawline(foo,0,linelens[foo],'200,200,200',rectid)

    ##print('<rect id="'+ rectid + '" x="' + str(startx) + '" y="' + str(starty) + endrect,file=outf)
    #print(foo,starty)

curpharr = 20
for foo in iltb:
    if( not re.search('^' + str(curbook) + '\.',foo)):
        continue
    m = re.search('lemma="([^"]+)"',iltb[foo])
    if(m):
        curlemma = m[1]
    else:
        continue
    if(curlemma in vocabs and vocabs[curlemma] < curpharr):
    #if( re.search('v..pi',iltb[foo])):
        print(foo,iltb[foo])
        wordn = int(re.sub('[0-9]+\.[0-9]+\.','',foo))
        lnum = re.sub('([0-9]+\.([0-9]+)\.[0-9]+$)','\g<1>',foo)
        print(lnum,wordn)
        label = foo
        rectid = label
        drawline(lnum,wordn-1,1,'300,150,150',rectid)
    if(curlemma in vocabs and vocabs[curlemma] == curpharr):
    #if( re.search('v..pi',iltb[foo])):
        print(foo,iltb[foo])
        wordn = int(re.sub('[0-9]+\.[0-9]+\.','',foo))
        lnum = re.sub('([0-9]+\.([0-9]+)\.[0-9]+$)','\g<1>',foo)
        print(lnum,wordn)
        label = foo
        rectid = label
        drawline(lnum,wordn-1,1,'100,300,150',rectid)
        
for foo in sbreaks:
    if( not re.search('^' + str(curbook) + '\.',foo)):
        continue
    
    wordn = int(re.sub('[0-9]+\.[0-9]+\.','',foo))
    
    lnum = re.sub('([0-9]+\.([0-9]+)\.[0-9]+$)','\g<1>',foo)
    print('sb',lnum,wordn)
    starty = getstarty(lnum)
    
    startx = getstartx(lnum,wordn) - 1
    wid = 2
    endrect = '"" height="' + str(lineheight) + '" width="' + str(wid) + '" fill="black"/>' 

    print('<rect id="'+ 'sn' + sbreaks[foo] + '" x="' + str(startx) + '" y="' + str(starty) + endrect,file=outf)
        
    

    
print('</svg>',file=outf)
print('done')
outf.close()
# Out:
# max 1.1 1
# max 1.1 2
# max 1.1 3
# max 1.1 4
# max 1.1 5
# max 1.2 6
# max 1.2 7
# max 1.2 8
# max 1.5 9
# max 1.10 10
# max 1.20 11
# max 1.63 12
# max 1.115 13
# max 1.115 14
# max 20.205 15
# 15
# booklines 1 611
# booklines 2 877
# booklines 3 461
# booklines 4 544
# booklines 5 909
# booklines 6 529
# booklines 7 482
# booklines 8 565
# booklines 9 713
# booklines 10 579
# booklines 11 848
# booklines 12 471
# booklines 13 837
# booklines 14 522
# booklines 15 746
# booklines 16 867
# booklines 17 761
# booklines 18 617
# booklines 19 424
# booklines 20 503
# booklines 21 611
# booklines 22 515
# booklines 23 897
# booklines 24 804
# rectid 1.1 5
# rectid 1.2 8
# rectid 1.3 6
# rectid 1.4 7
# rectid 1.5 9
# rectid 1.6 7
# rectid 1.7 8
# rectid 1.8 9
# rectid 1.9 9
# rectid 1.10 10
# rectid 1.11 5
# rectid 1.12 9
# rectid 1.13 8
# rectid 1.14 6
# rectid 1.15 9
# rectid 1.16 8
# rectid 1.17 7
# rectid 1.18 7
# rectid 1.19 9
# rectid 1.20 11
# rectid 1.21 6
# rectid 1.22 6
# ...
